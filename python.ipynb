# %% [markdown]
# Python IP

# %%
# Let's import the pandas library
import pandas as pd
# as well as the Numpy library
import numpy as np

# %% [markdown]
# Loading our datasets

# %%
# Creating a Dataframe from a csv file

df = pd.read_csv("Telcom_dataset.csv", delimiter=',')
df
# Out:
#      PRODUTC  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996     sms    100  2012-05-07 00:01:54.0  ...     OTHER  0c2371d9bc  1e751d08a4
# 4997   Voice      1  2012-05-07 00:01:54.0  ...     19e2e  5fb791cf56  65efe2bc62
# 4998   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  7773627c12  9ef9616350
# 4999   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  3f4af49d6c  969b8d0e39
# ...

# %%
# Renaming the columns in the above
# 1st column and datetime
df.rename(columns={'PRODUTC': 'PRODUCT', 'DATETIME': 'DATE_TIME', 'DW_A_NUMBER_INT': 'DW_A_NUMBER', 'DW_B_NUMBER_INT': 'DW_B_NUMBER'}, inplace=True)
df
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996     sms    100  2012-05-07 00:01:54.0  ...     OTHER  0c2371d9bc  1e751d08a4
# 4997   Voice      1  2012-05-07 00:01:54.0  ...     19e2e  5fb791cf56  65efe2bc62
# 4998   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  7773627c12  9ef9616350
# 4999   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  3f4af49d6c  969b8d0e39
# ...

# %%
df1 = pd.read_csv("Telcom_dataset2.csv", delimiter=',')
df1
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0        sms      0  2012-05-07 23:02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1      Voice      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2        sms      0  2012-05-07 23:04:06.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 3      Voice     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4        sms     25  2012-05-07 23:04:58.0  ...     19e2e  +bO+qkSonO  +bO+qkSonO
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996     sms      0  2012-05-08 00:01:53.0  ...     19e2e  896459aace  b7d00e59e4
# 4997     sms     25  2012-05-08 00:01:53.0  ...     19e2e  7e90b35166  211015b14d
# 4998     sms      0  2012-05-08 00:01:53.0  ...     19e2e  fe70e431df  c7ea989264
# 4999    data      0  2012-05-08 00:01:53.0  ...     OTHER  ffa6759bb2         NaN
# ...

# %%
df2 = pd.read_csv("Telcom_dataset3.csv", delimiter=',')
df2
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B      CELLID     SIET_ID
# 0      Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1        sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2      Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3        sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4998   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4999   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %%
# Renaming the columns in the above
# DW_A_NUMBER_INT, DW_B_NUMBER_INT, CELLID

df2.rename(columns={'DW_A_NUMBER_INT': 'DW_A_NUMBER', 'DW_B_NUMBER_INT': 'DW_B_NUMBER', 'CELLID': 'CELL_ID', 'SIET_ID': 'SITE_ID'}, inplace=True)
df2
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1        sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2      Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3        sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4998   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4999   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %%
path = '/content/cells_geo.csv'
df3 = pd.read_csv("/content/cells_geo.csv", delimiter=';')
df3
# Out:
#       Unnamed: 0    VILLES      STATUS  ...          AREA     CELL_ID   SITE_CODE
# 0              0    ADJAME  In Service  ...           NaN  fbb2e75af3  0bb492ef17
# 1              1    ADJAME  In Service  ...           NaN  1502501d78  0bb492ef17
# 2              2    ADJAME  In Service  ...           NaN  0c2e182a0c  0bb492ef17
# 3              3   ASSINIE  In Service  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4              4   ASSINIE  In Service  ...           NaN  7a1029d2ab  8a1e6ce31f
# ...          ...       ...         ...  ...           ...         ...         ...
# 3969        3969  ZUENOULA  In Service  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970        3970  ZUENOULA  In Service  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971        3971  ZUENOULA  In Service  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972        3972  ZUENOULA  In Service  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
# cleaning the geo.csv dataset
# identfying the missing values
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3974 entries, 0 to 3973
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    3974 non-null   int64
#  1   VILLES        3974 non-null   object
#  2   STATUS        3907 non-null   object
#  3   LOCALISATION  3974 non-null   object
#  4   DECOUPZONE    3974 non-null   object
#  5   ZONENAME      3968 non-null   object
#  6   LONGITUDE     3974 non-null   float64
#  7   LATITUDE      3974 non-null   float64
#  8   REGION        3974 non-null   object
#  9   AREA          3951 non-null   object
#  10  CELL_ID       3974 non-null   object
#  11  SITE_CODE     3974 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 372.7+ KB

# %%
# identifying duplicates 
df3.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3969    False
# 3970    False
# 3971    False
# 3972    False
# 3973    False
# Length: 3974, dtype: bool

# %%
# dropping duplicates
df3.drop_duplicates()
# Out:
#       Unnamed: 0    VILLES      STATUS  ...          AREA     CELL_ID   SITE_CODE
# 0              0    ADJAME  In Service  ...           NaN  fbb2e75af3  0bb492ef17
# 1              1    ADJAME  In Service  ...           NaN  1502501d78  0bb492ef17
# 2              2    ADJAME  In Service  ...           NaN  0c2e182a0c  0bb492ef17
# 3              3   ASSINIE  In Service  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4              4   ASSINIE  In Service  ...           NaN  7a1029d2ab  8a1e6ce31f
# ...          ...       ...         ...  ...           ...         ...         ...
# 3969        3969  ZUENOULA  In Service  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970        3970  ZUENOULA  In Service  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971        3971  ZUENOULA  In Service  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972        3972  ZUENOULA  In Service  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
# missing values
df3.isnull()
# Out:
#       Unnamed: 0  VILLES  STATUS  ...   AREA  CELL_ID  SITE_CODE
# 0          False   False   False  ...   True    False      False
# 1          False   False   False  ...   True    False      False
# 2          False   False   False  ...   True    False      False
# 3          False   False   False  ...   True    False      False
# 4          False   False   False  ...   True    False      False
# ...          ...     ...     ...  ...    ...      ...        ...
# 3969       False   False   False  ...  False    False      False
# 3970       False   False   False  ...  False    False      False
# 3971       False   False   False  ...  False    False      False
# 3972       False   False   False  ...  False    False      False
# 3973       False   False   False  ...  False    False      False
#
# [3974 rows x 12 columns]

# %%
# dropping missing observations
df3_no_missing = df3.dropna()
df3_no_missing
# Out:
#       Unnamed: 0    VILLES      STATUS  ...           AREA     CELL_ID   SITE_CODE
# 23            23     ABOBO  In Service  ...  ABIDJAN NORTH  f740406877  0f34c36ac5
# 24            24     ABOBO  In Service  ...  ABIDJAN NORTH  959e54c8f7  0f34c36ac5
# 25            25     ABOBO  In Service  ...  ABIDJAN NORTH  56b7e7000c  0f34c36ac5
# 26            26     ABOBO  In Service  ...  ABIDJAN NORTH  bc51c17a6f  0f34c36ac5
# 27            27     ABOBO  In Service  ...  ABIDJAN NORTH  e460975c9f  0f34c36ac5
# ...          ...       ...         ...  ...            ...         ...         ...
# 3969        3969  ZUENOULA  In Service  ...   CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970        3970  ZUENOULA  In Service  ...   CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971        3971  ZUENOULA  In Service  ...   CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972        3972  ZUENOULA  In Service  ...   CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
# renaming the site code to site id
df3_no_missing.rename(columns={'SITE_CODE': 'SITE_ID'}, inplace=True)
df3_no_missing
# Out:
#       Unnamed: 0    VILLES      STATUS  ...           AREA     CELL_ID     SITE_ID
# 23            23     ABOBO  In Service  ...  ABIDJAN NORTH  f740406877  0f34c36ac5
# 24            24     ABOBO  In Service  ...  ABIDJAN NORTH  959e54c8f7  0f34c36ac5
# 25            25     ABOBO  In Service  ...  ABIDJAN NORTH  56b7e7000c  0f34c36ac5
# 26            26     ABOBO  In Service  ...  ABIDJAN NORTH  bc51c17a6f  0f34c36ac5
# 27            27     ABOBO  In Service  ...  ABIDJAN NORTH  e460975c9f  0f34c36ac5
# ...          ...       ...         ...  ...            ...         ...         ...
# 3969        3969  ZUENOULA  In Service  ...   CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970        3970  ZUENOULA  In Service  ...   CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971        3971  ZUENOULA  In Service  ...   CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972        3972  ZUENOULA  In Service  ...   CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
path = '/content/cells_geo_description.xlsx'
df4 = pd.read_excel("/content/cells_geo_description.xlsx", header=1)
df4
# Out:
#          VILLES                                               City  String
# 0        STATUS                                  In Service or not  String
# 1  LOCALISATION                                  in ABIDJAN or not  String
# 2    DECOUPZONE                                  Geographical Zone  String
# 3      ZONENAME                                       Name of Zone  String
# 4     LONGITUDE                                          Longitude   Float
# 5      LATITUDE                                           Latitude   Float
# 6        REGION                                             Region  String
# 7          AREA                                               Area  String
# 8       CELL_ID                                     ID of the cell  String
# 9     SITE_CODE  Site (there are several cells per site, severa...  String

# %%
path = '/content/CDR_description.xlsx'
df5 = pd.read_excel("/content/CDR_description.xlsx", header=1)
df5
# Out:
#            PRODUCT                                       Voice or SMS   String
# 0            VALUE                                      Billing price  Integer
# 1        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 2     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 3  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 4  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 5        COUNTRY_A                  Country of party A (useless here)   String
# 6        COUNTRY_B                  Country of party B (useless here)   String
# 7          CELL_ID                                     ID of the cell   String
# 8          SITE_ID                                     ID of the SITE   String

# %%
# merging the three telcom datasets to get one dataframe
df_merge = pd.concat([df, df1, df2])
print(df_merge)
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4998   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4999   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %%
# I can use the info() method to output some general information about the dataframe
# this method helps me know whether there are missing values
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15003 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCT       15003 non-null  object
#  1   VALUE         15003 non-null  int64
#  2   DATE_TIME     15003 non-null  object
#  3   CELL_ON_SITE  15003 non-null  object
#  4   DW_A_NUMBER   15003 non-null  object
#  5   DW_B_NUMBER   15003 non-null  object
#  6   COUNTRY_A     15003 non-null  object
#  7   COUNTRY_B     15003 non-null  object
#  8   CELL_ID       15003 non-null  object
#  9   SITE_ID       13006 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.3+ MB

# %% [markdown]
# Cleaning our Data

# %%
# While doing data analysis, finding duplicates in your data is very important. 
# Delete duplicates in pandas
df_merge.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4996    False
# 4997    False
# 4998     True
# 4999    False
# 5000    False
# Length: 15003, dtype: bool

# %%
# dropping duplicates from our data
df_merge.drop_duplicates()
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4995   Voice     10  2012-05-09 00:01:43.0  ...     OTHER  6467daa1db  8a96bae9c1
# 4996   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4999   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15003 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCT       15003 non-null  object
#  1   VALUE         15003 non-null  int64
#  2   DATE_TIME     15003 non-null  object
#  3   CELL_ON_SITE  15003 non-null  object
#  4   DW_A_NUMBER   15003 non-null  object
#  5   DW_B_NUMBER   15003 non-null  object
#  6   COUNTRY_A     15003 non-null  object
#  7   COUNTRY_B     15003 non-null  object
#  8   CELL_ID       15003 non-null  object
#  9   SITE_ID       13006 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.3+ MB

# %%
# missing values
df_merge.isnull()
# Out:
#       PRODUCT  VALUE  DATE_TIME  ...  COUNTRY_B  CELL_ID  SITE_ID
# 0       False  False      False  ...      False    False    False
# 1       False  False      False  ...      False    False    False
# 2       False  False      False  ...      False    False    False
# 3       False  False      False  ...      False    False    False
# 4       False  False      False  ...      False    False    False
# ...       ...    ...        ...  ...        ...      ...      ...
# 4996    False  False      False  ...      False    False    False
# 4997    False  False      False  ...      False    False    False
# 4998    False  False      False  ...      False    False    False
# 4999    False  False      False  ...      False    False    False
# 5000    False  False      False  ...      False    False    False
#
# [15003 rows x 10 columns]

# %%
df_merge_no_missing = df_merge.dropna()
df_merge_no_missing
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4998   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4999   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %%
# dropping columns cell on site, country a and country b
df_merge_no_missing
df_merge_no_missing.drop(['CELL_ON_SITE', 'COUNTRY_A', 'COUNTRY_B'], axis=1, inplace=True)
# Out:
#      PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# 0      Voice      0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  ...  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  ...  051KhYDCpv  051KhYDCpv
# ...      ...    ...  ...         ...         ...
# 4996   Voice      0  ...  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  ...  7f1f2f889f  b4ddb9e93c
# 4998   Voice     32  ...  a4731e780e  d68260ef50
# 4999   Voice     30  ...  98ed726da2  b4130b54ab
# 5000   Voice     60  ...  1c11a2fcbb  6d70dae094
#
# [13006 rows x 7 columns]

# %%
#merging the telcom dataset and the cells geo.cvs
df_merged = pd.merge(df_merge_no_missing, df3_no_missing , how='outer')
df_merged
# Out:
#       PRODUCT  VALUE              DATE_TIME  ...  LATITUDE    REGION          AREA
# 0       Voice    0.0  2012-05-06 23:04:37.0  ...       NaN       NaN           NaN
# 1         sms    0.0  2012-05-06 23:40:48.0  ...       NaN       NaN           NaN
# 2         sms    0.0  2012-05-07 23:32:47.0  ...       NaN       NaN           NaN
# 3         sms    0.0  2012-05-07 23:52:21.0  ...       NaN       NaN           NaN
# 4        data    0.0  2012-05-07 23:53:21.0  ...       NaN       NaN           NaN
# ...       ...    ...                    ...  ...       ...       ...           ...
# 16881     NaN    NaN                    NaN  ...  7.428611  MARAHOUE  CENTRE NORTH
# 16882     NaN    NaN                    NaN  ...  7.428611  MARAHOUE  CENTRE NORTH
# 16883     NaN    NaN                    NaN  ...  7.444592  MARAHOUE  CENTRE NORTH
# 16884     NaN    NaN                    NaN  ...  7.444592  MARAHOUE  CENTRE NORTH
# ...

# %%
# dropping columns in the merged dataset
df_merged.drop(['Unnamed: 0', 'LONGITUDE', 'LATITUDE'], axis=1, inplace=True)
df_merged
# Out:
#       PRODUCT  VALUE  ...    REGION          AREA
# 0       Voice    0.0  ...       NaN           NaN
# 1         sms    0.0  ...       NaN           NaN
# 2         sms    0.0  ...       NaN           NaN
# 3         sms    0.0  ...       NaN           NaN
# 4        data    0.0  ...       NaN           NaN
# ...       ...    ...  ...       ...           ...
# 16881     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16882     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16883     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16884     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16885     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
#
# [16886 rows x 14 columns]

# %%
df_merged.duplicated()
df_merged.drop_duplicates()
# Out:
#       PRODUCT  VALUE  ...    REGION          AREA
# 0       Voice    0.0  ...       NaN           NaN
# 1         sms    0.0  ...       NaN           NaN
# 2         sms    0.0  ...       NaN           NaN
# 3         sms    0.0  ...       NaN           NaN
# 4        data    0.0  ...       NaN           NaN
# ...       ...    ...  ...       ...           ...
# 16881     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16882     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16883     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16884     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16885     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
#
# [16651 rows x 14 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16886 entries, 0 to 16885
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCT       13006 non-null  object
#  1   VALUE         13006 non-null  float64
#  2   DATE_TIME     13006 non-null  object
#  3   DW_A_NUMBER   13006 non-null  object
#  4   DW_B_NUMBER   13006 non-null  object
#  5   CELL_ID       16886 non-null  object
#  6   SITE_ID       16886 non-null  object
#  7   VILLES        3880 non-null   object
#  8   STATUS        3880 non-null   object
#  9   LOCALISATION  3880 non-null   object
#  10  DECOUPZONE    3880 non-null   object
#  11  ZONENAME      3880 non-null   object
#  12  REGION        3880 non-null   object
#  13  AREA          3880 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 1.9+ MB

# %%
df_merged.describe()
# Out:
#               VALUE
# count  13006.000000
# mean      27.304398
# std      111.025088
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       25.000000
# max     6750.000000

# %%
#missing values
df_merged.isnull()

# filling missing data with 0
df_merged.fillna(0)
# Out:
#       PRODUCT  VALUE  ...    REGION          AREA
# 0       Voice    0.0  ...         0             0
# 1         sms    0.0  ...         0             0
# 2         sms    0.0  ...         0             0
# 3         sms    0.0  ...         0             0
# 4        data    0.0  ...         0             0
# ...       ...    ...  ...       ...           ...
# 16881       0    0.0  ...  MARAHOUE  CENTRE NORTH
# 16882       0    0.0  ...  MARAHOUE  CENTRE NORTH
# 16883       0    0.0  ...  MARAHOUE  CENTRE NORTH
# 16884       0    0.0  ...  MARAHOUE  CENTRE NORTH
# 16885       0    0.0  ...  MARAHOUE  CENTRE NORTH
#
# [16886 rows x 14 columns]

# %% [markdown]
# Analysis

# %%
df_merged.describe()
# Out:
#               VALUE
# count  13006.000000
# mean      27.304398
# std      111.025088
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       25.000000
# max     6750.000000

# %%
df_merged
# Out:
#       PRODUCT  VALUE  ...    REGION          AREA
# 0       Voice    0.0  ...       NaN           NaN
# 1         sms    0.0  ...       NaN           NaN
# 2         sms    0.0  ...       NaN           NaN
# 3         sms    0.0  ...       NaN           NaN
# 4        data    0.0  ...       NaN           NaN
# ...       ...    ...  ...       ...           ...
# 16881     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16882     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16883     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16884     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
# 16885     NaN    NaN  ...  MARAHOUE  CENTRE NORTH
#
# [16886 rows x 14 columns]

# %%
# Which ones were the most used city for the three days?
df_merged.groupby(['VILLES', 'PRODUCT'])['VALUE'].sum()
# Out:
# Series([], Name: VALUE, dtype: float64)
